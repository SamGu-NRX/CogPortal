# %%
from pathlib import Path

# %%
"C:\home\my_song.mp3"
"C:\home\my_song.mp3"
"C:\home\my_song.mp3"
"C:\home\my_song.mp3"

# %%
path_to_song = Path("C:\home\my_song.mp3")

# %%
path_to_song.stem
# Out:
# 'my_song'
